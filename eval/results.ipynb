# %% [markdown]
# ### Test Results

# %% [markdown]
# #### Case 1

# %%
import pymesh
from utils import *

# %%
mesh = pymesh.load_mesh("../examples/data/two_spheres.ply")

# %%
method1_mesh = direct_repair(mesh)
method2_mesh = pymesh.compute_outer_hull(mesh)
method3_mesh = repair_meshlib(path="../examples/data/two_spheres.ply", details=compute_median_edge_length(mesh)/2) # Fix self-intersections by converting to voxels and back.
method4_mesh = repair_contour_original("../examples/SNResult/case1/combined_labels.obj")          # repair_contour() is now depricated
method5_mesh = repair_with_local_remesh(mesh)

# %%
full_evaluation2(mesh, method1_mesh, method2_mesh, method3_mesh, method4_mesh, method5_mesh)
# Out:
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | Metric                  |    Original |   PyMeshFix |      MeshFix |      Meshlib |   SurfaceNets |   Local Remesh |
# +=========================+=============+=============+==============+==============+===============+================+
# | vertices                |  952        |  476        |  917         | 3886         |   2023        |    937         |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | faces                   | 1896        |  948        | 1830         | 7768         |   4176        |   1870         |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | intersecting face pairs |  119        |    0        |    0         |    0         |      0        |      0         |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | volume                  |    7.07818  |    3.57206  |    6.61368   |    6.58615   |      4.51994  |      6.61002   |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | area                    |   22.5682   |   11.3654   |   19.0834    |   18.7355    |     41.9728   |     19.0839    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean aspect ratio       |    1.44276  |    1.38694  |   10.3517    |    1.54315   |      2.31394  |      1.44384   |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mMean condition         |    1.24015  |    1.18328  |   10.0668    |    1.28525   |      2.1209   |      1.2398    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean max angle          |   84.5364   |   84.758    |   88.9071    |   91.4155    |     83.0512   |     84.4893    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean min angle          |   41.6242   |   41.9123   |   37.6993    |   37.5538    |     41.2798   |     41.4381    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean scaled jacobian    |    0.757957 |    0.764245 |    0.688635  |    0.696323  |      0.751215 |      0.754435  |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean displacement       |  nan        |    0.22541  |    0.0237742 |    0.0643209 |      0.693402 |      0.0300835 |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean angle deviation    |   17.1776   |   17.2509   |   20.5737    |   21.5805    |     16.3528   |     17.1808    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | intact vertices (%)     |  nan        |   50        |   84.0336    |    0         |      0        |     76.9958    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+

# %% [markdown]
# #### Case 2

# %%
mesh2 = pymesh.load_mesh("../examples/data/three_spheres.ply")

# %%
method1_mesh2 = direct_repair(mesh2)
method2_mesh2 = pymesh.compute_outer_hull(mesh2)
method3_mesh2 = repair_meshlib(path="../examples/data/three_spheres.ply", details=compute_median_edge_length(mesh2)/2)
method4_mesh2 = repair_contour_original("../examples/SNResult/case2/combined_labels.obj")
method5_mesh2 = repair_with_local_remesh(mesh2)

# %%
full_evaluation2(mesh2, method1_mesh2, method2_mesh2, method3_mesh2, method4_mesh2, method5_mesh2)
# Out:
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | Metric                  |    Original |   PyMeshFix |      MeshFix |       Meshlib |   SurfaceNets |   Local Remesh |
# +=========================+=============+=============+==============+===============+===============+================+
# | vertices                | 1608        |  536        | 1576         |  6624         |   3605        |   1564         |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | faces                   | 3204        | 1068        | 3148         | 13244         |   7320        |   3124         |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | intersecting face pairs |  292        |    0        |    0         |     0         |      0        |      0         |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | volume                  |   11.9636   |    3.98785  |   11.0221    |    10.9887    |      7.52083  |     11.0126    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | area                    |   36.5995   |   12.1998   |   29.3751    |    28.8196    |     66.2729   |     29.3838    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mean aspect ratio       |    1.32852  |    1.32852  |    7.58477   |     1.56955   |      2.03969  |      1.3732    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mMean condition         |    1.14841  |    1.14841  |    7.32582   |     1.31022   |      1.86601  |      1.18108   |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mean max angle          |   81.7211   |   81.7211   |   88.1958    |    91.3883    |     80.4838   |     82.7455    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mean min angle          |   41.216    |   41.216    |   36.6265    |    37.6609    |     43.2653   |     41.0062    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mean scaled jacobian    |    0.756785 |    0.756785 |    0.674093  |     0.697055  |      0.781142 |      0.751746  |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mean displacement       |  nan        |    0.358335 |    0.0317006 |     0.0642545 |      1.18496  |      0.0381097 |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | mean angle deviation    |   15.7303   |   15.7303   |   20.1621    |    21.764     |     14.5785   |     16.3723    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+
# | intact vertices (%)     |  nan        |   33.3333   |   80.3483    |     0         |      0        |     70.6468    |
# +-------------------------+-------------+-------------+--------------+---------------+---------------+----------------+

# %% [markdown]
# #### Case 3

# %%
mesh3 = pymesh.load_mesh("../examples/data/sphere_cube.ply")

# %%
method1_mesh3 = direct_repair(mesh3)
method2_mesh3 = pymesh.compute_outer_hull(mesh3)
method3_mesh3 = repair_meshlib(path="../examples/data/sphere_cube.ply", details=compute_median_edge_length(mesh3)/2)
method4_mesh3 = repair_contour_original("../examples/SNResult/case3/combined_labels.obj")
method5_mesh3 = repair_with_local_remesh(mesh3)

# %%
full_evaluation2(mesh3, method1_mesh3, method2_mesh3, method3_mesh3, method4_mesh3, mesh5=method5_mesh3)
# Out:
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | Metric                  |    Original |   PyMeshFix |      MeshFix |      Meshlib |   SurfaceNets |   Local Remesh |
# +=========================+=============+=============+==============+==============+===============+================+
# | vertices                |  760        |  230        |  758         | 2776         |   1321        |    860         |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | faces                   | 1512        |  456        | 1512         | 5548         |   2656        |   1716         |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | intersecting face pairs |   99        |    0        |    0         |    0         |      0        |      0         |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | volume                  |   11.5887   |    6.95055  |   10.8456    |   10.7511    |      9.4714   |     10.8422    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | area                    |   34.6426   |   25.1159   |   29.9165    |   28.7493    |     58.2225   |     29.9154    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean aspect ratio       |    1.39028  |    2.20959  |    2.13189   |    1.54787   |      1.54015  |      1.42078   |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mMean condition         |    1.17609  |    1.87382  |    1.86243   |    1.29689   |      1.32961  |      1.20389   |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean max angle          |   86.4643   |   96.0991   |   90.4528    |   90.8321    |     85.4658   |     86.3096    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean min angle          |   41.6592   |   35.0129   |   38.041     |   37.5696    |     41.2127   |     40.8672    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean scaled jacobian    |    0.761911 |    0.648732 |    0.698354  |    0.697748  |      0.754868 |      0.748224  |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean displacement       |  nan        |    0.305105 |    0.0259377 |    0.0854343 |      1.53573  |      0.0366025 |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | mean angle deviation    |   17.9117   |   24.3704   |   20.8828    |   21.1474    |     17.5824   |     18.0721    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+
# | intact vertices (%)     |  nan        |   30.2632   |   86.7105    |    0         |      0        |     79.7368    |
# +-------------------------+-------------+-------------+--------------+--------------+---------------+----------------+

# %% [markdown]
# #### Case 4

# %%
mesh4 = pymesh.load_mesh("data/brain.ply")

# %%
method1_mesh4 = direct_repair(mesh4)
method2_mesh4 = pymesh.compute_outer_hull(mesh4)
method3_mesh4 = repair_meshlib(path="data/brain.ply", details=compute_median_edge_length(mesh4)/2)
method4_mesh4 = repair_contour(mesh4, voxel_size=compute_median_edge_length(mesh4)/2)
method5_mesh4 = repair_with_local_remesh(mesh4)

# %%
full_evaluation2(original=mesh4, mesh1=method1_mesh4, mesh2=method2_mesh4, mesh3=method3_mesh4, mesh4=method4_mesh4, mesh5=method5_mesh4)
